# %%
# %%timeit
def fetch_squares(max_root):
  squares = []
  for x in range(max_root):
    squares.append(x**2) 
  return squares

MAX = 5
for square in fetch_squares(MAX):
  square = square + 1
# Out:
# 100000 loops, best of 3: 2.5 µs per loop

# %%
# %%timeit
def fetch_squares(max_root):
  return [x**2 for x in range(max_root)]


MAX = 5
[square+1 in fetch_squares(MAX)]
# Out:
# 100000 loops, best of 3: 2.19 µs per loop
