# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# !pip install -q tensorflow==2.0.0-alpha0
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %%
mnist = tf.keras.datasets.mnist

# %%
(train_images, train_labels), (test_images, test_lables) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
models = tf.keras.models

# %%
layers = tf.keras.layers

# %%
network = models.Sequential()

# %%
network.add(layers.Dense(512, activation ='relu', input_shape=(28*28,)))

# %%
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
train_images = train_images.reshape(60000, 28*28).astype('float32') /255

# %%
test_images = test_images.reshape(10000, 28*28).astype('float32') /255

# %%
to_categorical = tf.keras.utils.to_categorical

# %%
train_labels[0:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
train_labels = to_categorical(train_labels)

# %%
test_labels = to_categorical(test_lables)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.2267 - accuracy: 0.9347
# Epoch 2/5
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.0888 - accuracy: 0.9730
# Epoch 3/5
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.0574 - accuracy: 0.9821
# Epoch 4/5
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.0395 - accuracy: 0.9882
# Epoch 5/5
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.0293 - accuracy: 0.9911

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 1s 60us/sample - loss: 0.0600 - accuracy: 0.9811

# %% [markdown]
# Chapter 1 is done

# %%
#laod dyfav data as pd then numpy array and check accuracy 
epcohs = 500

# %%
#testing a hypothesis
import numpy as np 
epochs = 500
list_a = [123]*epochs
list_b = [list_a, [2*a for a in list_a]]

# %%
agg_list = np.asarray(list_b)
mean_s = np.mean(agg_list, axis=0)

# %%
agg_list = [np.mean([x[i] for x in list_b]) for i in range(len(list_a))]

# %%
mean_s.shape
# Out:
# (500,)

# %%
len(agg_list)
# Out:
# 500
