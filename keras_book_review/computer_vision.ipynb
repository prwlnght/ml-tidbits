# %%
#understanding CNN, using data u

# %% [markdown]
# Understanding CNN
# Using Data augmentation to mitigate overfitting
# Using a pretrained convnet to do feature extraction
# Fine-tuning a pretrained convnet
# Visualizing what convnets learn and how they make classification decisions

# %%
#simple convnet for MNIST
# !pip install numpy==1.16.1
# !pip install -q tensorflow==2.0.0-alpha0

# %%
#all import statements 
import numpy as np 
import tensorflow as tf
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
layers = tf.keras.layers
models = tf.keras.models

model = models.Sequential()  #all models we use are sequential, unless they are recurrent
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.summary()

# %%
model2 = models.Sequential()  #all models we use are sequential, unless they are recurrent
model2.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 3)))
model2.add(layers.MaxPooling2D((2, 2)))
model2.add(layers.Conv2D(64, (3, 3), activation='relu'))
model2.add(layers.MaxPooling2D((2,2)))
model2.add(layers.Conv2D(64, (3, 3), activation='relu'))
model2.add(layers.Flatten())
model2.add(layers.Dense(64, activation='relu'))
model2.add(layers.Dense(10, activation='softmax'))
model2.summary()

# %%
32*3*3*3 + 32
# Out:
# 896

# %%
mnist = tf.keras.datasets.mnist
to_categorical = tf.keras.utils.to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images= train_images.reshape((train_images.shape[0], train_images.shape[1], train_images.shape[2], 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((test_images.shape[0], test_images.shape[1], test_images.shape[2], 1))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=64)

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 1s 61us/sample - loss: 0.0279 - acc: 0.9910
# [0.027926146635640907, 0.991]

# %%
layers = tf.keras.layers
models = tf.keras.models

model = models.Sequential()  #all models we use are sequential, unless they are recurrent
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.summary()

# %%
layers = tf.keras.layers
models = tf.keras.models

model = models.Sequential()  #all models we use are sequential, unless they are recurrent
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
#model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
#model.add(layers.MaxPooling2D((2,2)))
#=model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.summary()

# %%
#now downloading cats and dogs dataset at google drive
#now downloading ASL fingerspelling dataset for exploration 
#to test how the exploration goes. 
#todo follow along for vision tasks
#todo repeat for asl fingerspelling tasks and see what can be achieved!

# %%
#get to the training/test files
from google.colab import drive
drive.mount('/content/gdrive')
data_dir= '/content/gdrive/My Drive/workspace/colab_notebooks/data/kagglecatsanddogs_3367a'
